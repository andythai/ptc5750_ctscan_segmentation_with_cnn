# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Segmentação-usando-redes-neurais-tipo-C.N.N." data-toc-modified-id="Segmentação-usando-redes-neurais-tipo-C.N.N.-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Segmentação usando redes neurais tipo C.N.N.</a></span><ul class="toc-item"><li><span><a href="#Universidade-de-São-Paulo---Escola-Politécnica---PPGEE" data-toc-modified-id="Universidade-de-São-Paulo---Escola-Politécnica---PPGEE-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Universidade de São Paulo - Escola Politécnica - PPGEE</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Segmentação usando redes neurais tipo C.N.N.
#
# ## Universidade de São Paulo - Escola Politécnica - PPGEE
#
# **Disciplina: PTC5750 / 2017 - 3º Período**
#
# **Docente Responsável: Sérgio Shiguemi Furuie**
#
# Aluno: Fábio T. Sancinetti - N. USP: 10156476

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import tensorflow as tf
import keras

from keras import backend as K
from keras import losses

from keras.models import Model, Sequential
from keras.objectives import categorical_crossentropy

from keras.layers import Input, concatenate
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, Conv2DTranspose, ZeroPadding2D

from keras.optimizers import Adam, Adadelta, Adamax, Nadam, Adagrad, SGD, RMSprop
from keras.callbacks import ModelCheckpoint, Callback

from keras.initializers import RandomUniform, RandomNormal
# Out:
# Using TensorFlow backend.

# %%
class PatientData(object):
    """
    
    PatientData looks for files of 3DIRCAD database.
    This database contains DICOM files and data is split into folders.
    PATIENT_DICOM folder contains original original CT Images
    MASKS_DICOM contains a list of several folders. Each folder is named
    according to the organ highlighted in the masks of the files within.
    During PatientData initialization, it will look for the folder pointed at
    root_dir and will load files named with same name on MASKS_DICOM/<organ name>/*
    
    """
    def __init__(self, root_dir, oi, file_extension=".dcm"):
        import os, re
        
        patient_images = {}

        for root, dirs, files in os.walk(root_dir):
            for file in files:
                if file.endswith(file_extension):
                    if 'PATIENT_DICOM' in root:
                        if not patient_images.get(file,None):
                            patient_images[file] = {}
                        p = os.path.join(root,file)
                        patient_images[file]['real'] = p
                    elif 'MASKS_DICOM' in root:
                        if not patient_images.get(file,None):
                            patient_images[file] = {}
                        p = os.path.join(root,file)
                        rs = re.match('.*MASKS_DICOM/(.*)/.*', str(p))
                        patient_images[file][rs.groups()[0]] = p

        self.oi = oi
        self.X = []
        self.Y = []
        
        for k,v in patient_images.items():
            for k1,v1 in v.items():
                if k1 == self.oi:
                    self.X.append(v['real'])
                    self.Y.append(v1)
        
        if len(self.X) != len(self.Y):
            raise Exception("number of input images (%d) does not match number of training samples (%d)" % 
                            (len(self.X),len(self.Y)))
   
            
    def normalize(self, img):
        arr = img.copy().astype(np.float)
        M = np.float(np.max(img))
        if M != 0:
            arr *= 1./M
        return arr
    

    def add_gauss_noise(self, inp, expected_noise_ratio=0.05):
        image = inp.copy()
        if len(image.shape) == 2:
            row,col= image.shape
            ch = 1
        else:
            row,col,ch= image.shape
        mean = 0.
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col)) * expected_noise_ratio
        gauss = gauss.reshape(row,col)
        noisy = image + gauss
        return noisy

    def get_data(self, noisy=False, split_part=0.5, resize_side=None, verbose=False):
        from scipy.ndimage.interpolation import zoom        
        from random import shuffle
        import pydicom as dicom
        
        im_X = []
        im_Y = []
        for i in range(len(self.X)):
            img_x = dicom.read_file(self.X[i]).pixel_array
            img_y = dicom.read_file(self.Y[i]).pixel_array
            if resize_side != None:
                ratio = resize_side / 512.
                img_x = zoom(img_x, ratio).copy()
                img_y = zoom(img_y, ratio).copy()
            img_x = self.normalize(img_x)
            img_y = self.normalize(img_y)

            if np.sum(img_y) < 5.:
                if np.random.randint(1,10) <= 5:
                    if verbose:
                        print("discarding a very zero like image %s (%f)" % (self.Y[i],np.sum(img_y)))
                    continue
            if noisy:
                img_x = self.add_gauss_noise(img_x)
                img_y = self.add_gauss_noise(img_y)
            im_X.append(img_x)
            im_Y.append(img_y)
            
        train_limit = int(len(im_X)*split_part)

        indexes = list(range(len(im_X)))
        shuffle(indexes)            

        shuffleX = [im_X[c] for c in indexes]
        shuffleY = [im_Y[c] for c in indexes]

        train_x = shuffleX[0:train_limit]
        test_x = shuffleX[train_limit:]
        train_y = shuffleY[0:train_limit]
        test_y = shuffleY[train_limit:]
        
        return train_x, train_y, test_x, test_y

# %%
root_dir = "../data/3Dircadb1.1/"

# %%
sample_height, sample_width = (128,128)
output_width, output_height = (128, 128)
img_tot_size = sample_width*sample_height

# %%
sess = tf.Session()
K.set_session(sess)

# %%
pd = PatientData(root_dir, 'bone') # Also works for 'liver'

# %%
data = pd.get_data(False, 0.75, sample_width) # Using 75% for training
train_x, train_y, test_x, test_y = map(np.array, data)
print("Using %s images for training and %s images for testing" % (len(train_x), len(test_x)))
# Out:
# Using 0 images for training and 0 images for testing

# %%
# Displaying some samples of the input
lines = min(4,len(train_x)) # len(imgs_mask_test) #16
fig, axarr = plt.subplots(lines, 2, figsize=(60,lines*10), sharex=True, sharey=False)

tot_dice = 0.
for i in range(0,lines):
    
    axarr[i,0].imshow(train_x[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,1].imshow(train_y[i].reshape(output_width, output_height), cmap='gray')
    
    for x in range(2):
        axarr[i,x].axis('off')

fig.tight_layout()
fig.subplots_adjust(top=0.975)
plt.show()

# %%
train_x = np.array([t.reshape(sample_width, sample_height,1) for t in train_x])
train_y = np.array([t.reshape(sample_width, sample_height,1) for t in train_y])
test_x  = np.array([t.reshape(sample_width, sample_height,1) for t in test_x])
test_y  = np.array([t.reshape(sample_width, sample_height,1) for t in test_y])

# %%
def get_model(optimizer, loss_metric, metrics, lr=1e-3):
    inputs = Input((sample_width, sample_height, 1))
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    drop1 = Dropout(0.5)(pool1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(drop1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    drop2 = Dropout(0.5)(pool2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(drop2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    drop3 = Dropout(0.3)(pool3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(drop3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    drop4 = Dropout(0.3)(pool4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(drop4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    model = Model(inputs=[inputs], outputs=[conv10])

    # working with dice and adam
    model.compile(optimizer=Adam(lr=1e-3, decay=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Adamax
    #model.compile(optimizer=Adamax(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #SGD
    #model.compile(optimizer=SGD(lr=1e-2, momentum=0.8), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Nadam
    #model.compile(optimizer=Nadam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    #Adadelta
    #model.compile(optimizer=Nadam(lr=1e-3), loss=dice_coef_loss, metrics=[dice_coef])
    
    return model

# %%
smooth = 1.

# Dice Coefficient to work with Tensorflow
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

# Dice Coefficient to work outside Tensorflow
def dice_coef_2(y_true, y_pred):
    side = len(y_true[0])
    y_true_f = y_true.reshape(side*side)
    y_pred_f = y_pred.reshape(side*side)
    intersection = sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (sum(y_true_f) + sum(y_pred_f) + smooth)

# %%
model = get_model(optimizer=Adam, loss_metric=dice_coef_loss, metrics=[dice_coef], lr=1e-3)

# %%
observe_var = 'dice_coef'
strategy = 'max' # greater dice_coef is better

#observe_var = 'loss' # for binary crossentropy 
#strategy = 'in' # smallest loss is better

#model_checkpoint = ModelCheckpoint('ptc5750.h5', monitor=observe_var, save_best_only=True)
#model_reset = ObserveTrainingFailure(observe_var,strategy, -1 , 10)

# %%
start_time = time.time()

history = model.fit(train_x, train_y, batch_size=int(len(train_x)/4),
          epochs=150, verbose=1, shuffle=True, validation_split=0.2)


elapsed_time = time.time() - start_time
print("Elapsed time: ", elapsed_time)
# Out:
# Train on 146 samples, validate on 37 samples
# Epoch 1/150
# 146/146 [==============================] - 2s 13ms/step - loss: -0.1152 - dice_coef: 0.1152 - val_loss: -0.1142 - val_dice_coef: 0.1142
# Epoch 2/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.1274 - dice_coef: 0.1274 - val_loss: -0.1548 - val_dice_coef: 0.1548
# Epoch 3/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.2240 - dice_coef: 0.2240 - val_loss: -0.3984 - val_dice_coef: 0.3984
# Epoch 4/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.4316 - dice_coef: 0.4316 - val_loss: -0.4940 - val_dice_coef: 0.4940
# Epoch 5/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.4969 - dice_coef: 0.4969 - val_loss: -0.5469 - val_dice_coef: 0.5469
# Epoch 6/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.5252 - dice_coef: 0.5252 - val_loss: -0.5446 - val_dice_coef: 0.5446
# Epoch 7/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.5728 - dice_coef: 0.5728 - val_loss: -0.6166 - val_dice_coef: 0.6166
# Epoch 8/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6335 - dice_coef: 0.6335 - val_loss: -0.6846 - val_dice_coef: 0.6846
# Epoch 9/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6815 - dice_coef: 0.6815 - val_loss: -0.7069 - val_dice_coef: 0.7069
# Epoch 10/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7041 - dice_coef: 0.7041 - val_loss: -0.7249 - val_dice_coef: 0.7249
# Epoch 11/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7225 - dice_coef: 0.7225 - val_loss: -0.7417 - val_dice_coef: 0.7417
# Epoch 12/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7370 - dice_coef: 0.7370 - val_loss: -0.7550 - val_dice_coef: 0.7550
# Epoch 13/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7507 - dice_coef: 0.7507 - val_loss: -0.7697 - val_dice_coef: 0.7697
# Epoch 14/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7345 - dice_coef: 0.7345 - val_loss: -0.7172 - val_dice_coef: 0.7172
# Epoch 15/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7022 - dice_coef: 0.7022 - val_loss: -0.6913 - val_dice_coef: 0.6913
# Epoch 16/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7035 - dice_coef: 0.7035 - val_loss: -0.7452 - val_dice_coef: 0.7452
# Epoch 17/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7408 - dice_coef: 0.7408 - val_loss: -0.6424 - val_dice_coef: 0.6424
# Epoch 18/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6197 - dice_coef: 0.6197 - val_loss: -0.6652 - val_dice_coef: 0.6652
# Epoch 19/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6686 - dice_coef: 0.6686 - val_loss: -0.6801 - val_dice_coef: 0.6801
# Epoch 20/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6771 - dice_coef: 0.6771 - val_loss: -0.6940 - val_dice_coef: 0.6940
# Epoch 21/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6939 - dice_coef: 0.6939 - val_loss: -0.7172 - val_dice_coef: 0.7172
# Epoch 22/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7160 - dice_coef: 0.7160 - val_loss: -0.7322 - val_dice_coef: 0.7322
# Epoch 23/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7469 - dice_coef: 0.7469 - val_loss: -0.6795 - val_dice_coef: 0.6795
# Epoch 24/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6689 - dice_coef: 0.6689 - val_loss: -0.0216 - val_dice_coef: 0.0216
# Epoch 25/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.5044 - dice_coef: 0.5044 - val_loss: -0.6960 - val_dice_coef: 0.6960
# Epoch 26/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7168 - dice_coef: 0.7168 - val_loss: -0.7269 - val_dice_coef: 0.7269
# Epoch 27/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7306 - dice_coef: 0.7306 - val_loss: -0.7604 - val_dice_coef: 0.7604
# Epoch 28/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7752 - dice_coef: 0.7752 - val_loss: -0.7861 - val_dice_coef: 0.7861
# Epoch 29/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8069 - dice_coef: 0.8069 - val_loss: -0.8043 - val_dice_coef: 0.8043
# Epoch 30/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7566 - dice_coef: 0.7566 - val_loss: -0.6547 - val_dice_coef: 0.6547
# Epoch 31/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.6411 - dice_coef: 0.6411 - val_loss: -0.6874 - val_dice_coef: 0.6874
# Epoch 32/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7088 - dice_coef: 0.7088 - val_loss: -0.7386 - val_dice_coef: 0.7386
# Epoch 33/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7311 - dice_coef: 0.7311 - val_loss: -0.7489 - val_dice_coef: 0.7489
# Epoch 34/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.7694 - dice_coef: 0.7694 - val_loss: -0.7833 - val_dice_coef: 0.7833
# Epoch 35/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8083 - dice_coef: 0.8083 - val_loss: -0.8010 - val_dice_coef: 0.8010
# Epoch 36/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8210 - dice_coef: 0.8210 - val_loss: -0.8122 - val_dice_coef: 0.8122
# Epoch 37/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8378 - dice_coef: 0.8378 - val_loss: -0.8257 - val_dice_coef: 0.8257
# Epoch 38/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8398 - dice_coef: 0.8398 - val_loss: -0.8162 - val_dice_coef: 0.8162
# Epoch 39/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8412 - dice_coef: 0.8412 - val_loss: -0.8459 - val_dice_coef: 0.8459
# Epoch 40/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8607 - dice_coef: 0.8607 - val_loss: -0.8538 - val_dice_coef: 0.8538
# Epoch 41/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8693 - dice_coef: 0.8693 - val_loss: -0.8445 - val_dice_coef: 0.8445
# Epoch 42/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8694 - dice_coef: 0.8694 - val_loss: -0.8642 - val_dice_coef: 0.8642
# Epoch 43/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8583 - dice_coef: 0.8583 - val_loss: -0.8593 - val_dice_coef: 0.8593
# Epoch 44/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8735 - dice_coef: 0.8735 - val_loss: -0.8653 - val_dice_coef: 0.8653
# Epoch 45/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8833 - dice_coef: 0.8833 - val_loss: -0.8567 - val_dice_coef: 0.8567
# Epoch 46/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8828 - dice_coef: 0.8828 - val_loss: -0.8795 - val_dice_coef: 0.8795
# Epoch 47/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8919 - dice_coef: 0.8919 - val_loss: -0.8699 - val_dice_coef: 0.8699
# Epoch 48/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8913 - dice_coef: 0.8913 - val_loss: -0.8622 - val_dice_coef: 0.8622
# Epoch 49/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8918 - dice_coef: 0.8918 - val_loss: -0.8589 - val_dice_coef: 0.8589
# Epoch 50/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8795 - dice_coef: 0.8795 - val_loss: -0.8941 - val_dice_coef: 0.8941
# Epoch 51/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8940 - dice_coef: 0.8940 - val_loss: -0.8757 - val_dice_coef: 0.8757
# Epoch 52/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8844 - dice_coef: 0.8844 - val_loss: -0.8896 - val_dice_coef: 0.8896
# Epoch 53/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8987 - dice_coef: 0.8987 - val_loss: -0.8631 - val_dice_coef: 0.8631
# Epoch 54/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.8969 - dice_coef: 0.8969 - val_loss: -0.9026 - val_dice_coef: 0.9026
# Epoch 55/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9103 - dice_coef: 0.9103 - val_loss: -0.8861 - val_dice_coef: 0.8861
# Epoch 56/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9174 - dice_coef: 0.9174 - val_loss: -0.9105 - val_dice_coef: 0.9105
# Epoch 57/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9191 - dice_coef: 0.9191 - val_loss: -0.9189 - val_dice_coef: 0.9189
# Epoch 58/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9259 - dice_coef: 0.9259 - val_loss: -0.9202 - val_dice_coef: 0.9202
# Epoch 59/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9314 - dice_coef: 0.9314 - val_loss: -0.9162 - val_dice_coef: 0.9162
# Epoch 60/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9235 - dice_coef: 0.9235 - val_loss: -0.9062 - val_dice_coef: 0.9062
# Epoch 61/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9236 - dice_coef: 0.9236 - val_loss: -0.9173 - val_dice_coef: 0.9173
# Epoch 62/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9266 - dice_coef: 0.9266 - val_loss: -0.9284 - val_dice_coef: 0.9284
# Epoch 63/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9333 - dice_coef: 0.9333 - val_loss: -0.9158 - val_dice_coef: 0.9158
# Epoch 64/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9332 - dice_coef: 0.9332 - val_loss: -0.9153 - val_dice_coef: 0.9153
# Epoch 65/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9261 - dice_coef: 0.9261 - val_loss: -0.9175 - val_dice_coef: 0.9175
# Epoch 66/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9214 - dice_coef: 0.9214 - val_loss: -0.9258 - val_dice_coef: 0.9258
# Epoch 67/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9265 - dice_coef: 0.9265 - val_loss: -0.9277 - val_dice_coef: 0.9277
# Epoch 68/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9324 - dice_coef: 0.9324 - val_loss: -0.9398 - val_dice_coef: 0.9398
# Epoch 69/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9422 - dice_coef: 0.9422 - val_loss: -0.9397 - val_dice_coef: 0.9397
# Epoch 70/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9455 - dice_coef: 0.9455 - val_loss: -0.9427 - val_dice_coef: 0.9427
# Epoch 71/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9453 - dice_coef: 0.9453 - val_loss: -0.9492 - val_dice_coef: 0.9492
# Epoch 72/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9454 - dice_coef: 0.9454 - val_loss: -0.9215 - val_dice_coef: 0.9215
# Epoch 73/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9387 - dice_coef: 0.9387 - val_loss: -0.9185 - val_dice_coef: 0.9185
# Epoch 74/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9231 - dice_coef: 0.9231 - val_loss: -0.9349 - val_dice_coef: 0.9349
# Epoch 75/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9387 - dice_coef: 0.9387 - val_loss: -0.9358 - val_dice_coef: 0.9358
# Epoch 76/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9432 - dice_coef: 0.9432 - val_loss: -0.9446 - val_dice_coef: 0.9446
# Epoch 77/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9500 - dice_coef: 0.9500 - val_loss: -0.9553 - val_dice_coef: 0.9553
# Epoch 78/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9538 - dice_coef: 0.9538 - val_loss: -0.9524 - val_dice_coef: 0.9524
# Epoch 79/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9542 - dice_coef: 0.9542 - val_loss: -0.9213 - val_dice_coef: 0.9213
# Epoch 80/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9309 - dice_coef: 0.9309 - val_loss: -0.9548 - val_dice_coef: 0.9548
# Epoch 81/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9516 - dice_coef: 0.9516 - val_loss: -0.9429 - val_dice_coef: 0.9429
# Epoch 82/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9496 - dice_coef: 0.9496 - val_loss: -0.9519 - val_dice_coef: 0.9519
# Epoch 83/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9549 - dice_coef: 0.9549 - val_loss: -0.9465 - val_dice_coef: 0.9465
# Epoch 84/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9556 - dice_coef: 0.9556 - val_loss: -0.9501 - val_dice_coef: 0.9501
# Epoch 85/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9523 - dice_coef: 0.9523 - val_loss: -0.9504 - val_dice_coef: 0.9504
# Epoch 86/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9560 - dice_coef: 0.9560 - val_loss: -0.9563 - val_dice_coef: 0.9563
# Epoch 87/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9584 - dice_coef: 0.9584 - val_loss: -0.9559 - val_dice_coef: 0.9559
# Epoch 88/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9592 - dice_coef: 0.9592 - val_loss: -0.9614 - val_dice_coef: 0.9614
# Epoch 89/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9613 - dice_coef: 0.9613 - val_loss: -0.9576 - val_dice_coef: 0.9576
# Epoch 90/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9565 - dice_coef: 0.9565 - val_loss: -0.9627 - val_dice_coef: 0.9627
# Epoch 91/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9622 - dice_coef: 0.9622 - val_loss: -0.9573 - val_dice_coef: 0.9573
# Epoch 92/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9624 - dice_coef: 0.9624 - val_loss: -0.9617 - val_dice_coef: 0.9617
# Epoch 93/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9632 - dice_coef: 0.9632 - val_loss: -0.9584 - val_dice_coef: 0.9584
# Epoch 94/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9611 - dice_coef: 0.9611 - val_loss: -0.9600 - val_dice_coef: 0.9600
# Epoch 95/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9617 - dice_coef: 0.9617 - val_loss: -0.9638 - val_dice_coef: 0.9638
# Epoch 96/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9662 - dice_coef: 0.9662 - val_loss: -0.9643 - val_dice_coef: 0.9643
# Epoch 97/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9651 - dice_coef: 0.9651 - val_loss: -0.9644 - val_dice_coef: 0.9644
# Epoch 98/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9661 - dice_coef: 0.9661 - val_loss: -0.9601 - val_dice_coef: 0.9601
# Epoch 99/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9626 - dice_coef: 0.9626 - val_loss: -0.9616 - val_dice_coef: 0.9616
# Epoch 100/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9615 - dice_coef: 0.9615 - val_loss: -0.9612 - val_dice_coef: 0.9612
# Epoch 101/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9648 - dice_coef: 0.9648 - val_loss: -0.9659 - val_dice_coef: 0.9659
# Epoch 102/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9643 - dice_coef: 0.9643 - val_loss: -0.9673 - val_dice_coef: 0.9673
# Epoch 103/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9667 - dice_coef: 0.9667 - val_loss: -0.9672 - val_dice_coef: 0.9672
# Epoch 104/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9684 - dice_coef: 0.9684 - val_loss: -0.9657 - val_dice_coef: 0.9657
# Epoch 105/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9674 - dice_coef: 0.9674 - val_loss: -0.9501 - val_dice_coef: 0.9501
# Epoch 106/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9550 - dice_coef: 0.9550 - val_loss: -0.9592 - val_dice_coef: 0.9592
# Epoch 107/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9601 - dice_coef: 0.9601 - val_loss: -0.9663 - val_dice_coef: 0.9663
# Epoch 108/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9629 - dice_coef: 0.9629 - val_loss: -0.9643 - val_dice_coef: 0.9643
# Epoch 109/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9652 - dice_coef: 0.9652 - val_loss: -0.9649 - val_dice_coef: 0.9649
# Epoch 110/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9642 - dice_coef: 0.9642 - val_loss: -0.9630 - val_dice_coef: 0.9630
# Epoch 111/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9634 - dice_coef: 0.9634 - val_loss: -0.9672 - val_dice_coef: 0.9672
# Epoch 112/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9627 - dice_coef: 0.9627 - val_loss: -0.9586 - val_dice_coef: 0.9586
# Epoch 113/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9623 - dice_coef: 0.9623 - val_loss: -0.9634 - val_dice_coef: 0.9634
# Epoch 114/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9633 - dice_coef: 0.9633 - val_loss: -0.9662 - val_dice_coef: 0.9662
# Epoch 115/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9683 - dice_coef: 0.9683 - val_loss: -0.9703 - val_dice_coef: 0.9703
# Epoch 116/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9690 - dice_coef: 0.9690 - val_loss: -0.9582 - val_dice_coef: 0.9582
# Epoch 117/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9629 - dice_coef: 0.9629 - val_loss: -0.9683 - val_dice_coef: 0.9683
# Epoch 118/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9684 - dice_coef: 0.9684 - val_loss: -0.9683 - val_dice_coef: 0.9683
# Epoch 119/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9677 - dice_coef: 0.9677 - val_loss: -0.9647 - val_dice_coef: 0.9647
# Epoch 120/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9657 - dice_coef: 0.9657 - val_loss: -0.9650 - val_dice_coef: 0.9650
# Epoch 121/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9650 - dice_coef: 0.9650 - val_loss: -0.9683 - val_dice_coef: 0.9683
# Epoch 122/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9668 - dice_coef: 0.9668 - val_loss: -0.9699 - val_dice_coef: 0.9699
# Epoch 123/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9706 - dice_coef: 0.9706 - val_loss: -0.9689 - val_dice_coef: 0.9689
# Epoch 124/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9700 - dice_coef: 0.9700 - val_loss: -0.9697 - val_dice_coef: 0.9697
# Epoch 125/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9698 - dice_coef: 0.9698 - val_loss: -0.9715 - val_dice_coef: 0.9715
# Epoch 126/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9696 - dice_coef: 0.9696 - val_loss: -0.9707 - val_dice_coef: 0.9707
# Epoch 127/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9714 - dice_coef: 0.9714 - val_loss: -0.9700 - val_dice_coef: 0.9700
# Epoch 128/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9714 - dice_coef: 0.9714 - val_loss: -0.9693 - val_dice_coef: 0.9693
# Epoch 129/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9703 - dice_coef: 0.9703 - val_loss: -0.9676 - val_dice_coef: 0.9676
# Epoch 130/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9695 - dice_coef: 0.9695 - val_loss: -0.9716 - val_dice_coef: 0.9716
# Epoch 131/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9712 - dice_coef: 0.9712 - val_loss: -0.9705 - val_dice_coef: 0.9705
# Epoch 132/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9720 - dice_coef: 0.9720 - val_loss: -0.9711 - val_dice_coef: 0.9711
# Epoch 133/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9710 - dice_coef: 0.9710 - val_loss: -0.9663 - val_dice_coef: 0.9663
# Epoch 134/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9691 - dice_coef: 0.9691 - val_loss: -0.9725 - val_dice_coef: 0.9725
# Epoch 135/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9720 - dice_coef: 0.9720 - val_loss: -0.9719 - val_dice_coef: 0.9719
# Epoch 136/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9727 - dice_coef: 0.9727 - val_loss: -0.9720 - val_dice_coef: 0.9720
# Epoch 137/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9732 - dice_coef: 0.9732 - val_loss: -0.9727 - val_dice_coef: 0.9727
# Epoch 138/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9739 - dice_coef: 0.9739 - val_loss: -0.9738 - val_dice_coef: 0.9738
# Epoch 139/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9745 - dice_coef: 0.9745 - val_loss: -0.9754 - val_dice_coef: 0.9754
# Epoch 140/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9757 - dice_coef: 0.9757 - val_loss: -0.9740 - val_dice_coef: 0.9740
# Epoch 141/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9738 - dice_coef: 0.9738 - val_loss: -0.9752 - val_dice_coef: 0.9752
# Epoch 142/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9750 - dice_coef: 0.9750 - val_loss: -0.9742 - val_dice_coef: 0.9742
# Epoch 143/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9747 - dice_coef: 0.9747 - val_loss: -0.9750 - val_dice_coef: 0.9750
# Epoch 144/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9742 - dice_coef: 0.9742 - val_loss: -0.9737 - val_dice_coef: 0.9737
# Epoch 145/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9754 - dice_coef: 0.9754 - val_loss: -0.9746 - val_dice_coef: 0.9746
# Epoch 146/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9738 - dice_coef: 0.9738 - val_loss: -0.9743 - val_dice_coef: 0.9743
# Epoch 147/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9738 - dice_coef: 0.9738 - val_loss: -0.9736 - val_dice_coef: 0.9736
# Epoch 148/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9736 - dice_coef: 0.9736 - val_loss: -0.9747 - val_dice_coef: 0.9747
# Epoch 149/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9755 - dice_coef: 0.9755 - val_loss: -0.9725 - val_dice_coef: 0.9725
# Epoch 150/150
# 146/146 [==============================] - 1s 6ms/step - loss: -0.9720 - dice_coef: 0.9720 - val_loss: -0.9695 - val_dice_coef: 0.9695
# Elapsed time:  131.00311064720154

# %%
print(history.history.keys())

# %%
# list all data in history

# summarize history for accuracy
plt.plot(history.history['dice_coef'])
plt.title('Model Accuracy')
plt.ylabel('Dice Coef.')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
imgs_mask_test = model.predict(test_x, verbose=1)

tot_dice = 0.
dices = []
for i in range(len(imgs_mask_test)):
    r = dice_coef_2(test_y[i],imgs_mask_test[i])
    dices.append(r)
    tot_dice += r
    
avg_dice = tot_dice/float(len(imgs_mask_test))
print(avg_dice)
# Out:
# 61/61 [==============================] - 0s 3ms/step
# 0.871098569265

# %%
postProcess = True
if postProcess:        
    avg = np.average(imgs_mask_test)
    for k in range(len(imgs_mask_test)):
        im = imgs_mask_test[k]
        m = np.max(im)
        for i in range(len(im)):
            for j in range(len(im[i])):
                # remove low confidence results helps to increase dice result
                if im[i,j] < (0.5):
                    im[i,j] = 0.
    
    tot_dice = 0.
    dices = []
    for i in range(len(imgs_mask_test)):
        r = dice_coef_2(test_y[i],imgs_mask_test[i])
        dices.append(r)
        tot_dice += r
        

    avg_dice = tot_dice/float(len(imgs_mask_test))
    print(avg_dice)
# Out:
# 0.871763577083

# %%
# Displaying some results
lines = max(15,len(imgs_mask_test))
fig, axarr = plt.subplots(lines, 3, figsize=(60,lines*10), sharex=True, sharey=False)

output_width, output_height = (128, 128)
for i in range(0,lines):
    axarr[i,0].imshow(test_x[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,1].imshow(test_y[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,2].imshow(imgs_mask_test[i].reshape(output_width, output_height), cmap='gray')
    axarr[i,2].set_title('Dice Coef = ' + str(dices[i]),fontsize=45,ha='center')
    
    for x in range(3):
        axarr[i,x].axis('off')

fig.suptitle('Dice average = ' + str(avg_dice) ,fontsize=60)
fig.tight_layout()
fig.subplots_adjust(top=0.975)
plt.show()
